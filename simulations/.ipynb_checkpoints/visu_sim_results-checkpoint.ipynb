# %%
source('4_2_plot_results.R')

# %%
fig_31 = ggplot_results(dir='../../../github-bayestime-analysis', dat_name='N100_M80', 
                      idx_sim=31, title_mean='N=100 & M=80%', fpc_range=c(-0.45, 2.75))

# %%
fig_31
# Out:
# Warning message:
# “Removed 272 row(s) containing missing values (geom_path).”
# $figure_fpc
# plot without title

# %%
fig_25 = ggplot_results(dir='../../../github-bayestime-analysis', dat_name='N100_M80', 
                      idx_sim=25, title_mean='N=100 & M=80% (idx 25)', fpc_range=c(-0.45, 2.75))

# %%
plot_grid(fig_31$figure_mean, fig_25$figure_mean, fig_31$figure_fpc, fig_25$figure_fpc,
          labels = c('A', 'B', 'C', 'D'), 
          hjust = 0, vjust = 1) 
ggsave('figures/sim_fig1.png', width=7, height=7, dpi=300)
# Out:
# Warning message:
# “Removed 272 row(s) containing missing values (geom_path).”
# Warning message:
# “Removed 266 row(s) containing missing values (geom_path).”
# plot without title
